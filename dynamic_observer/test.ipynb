# %%
from ct_scorematching import *
# Out:
# /homes/pr450/repos/research_projects/sampling_ddpm/dynamic_observer/ct_scorematching.py:13: SyntaxWarning: invalid escape sequence '\i'
#   """
# /homes/pr450/repos/research_projects/sampling_ddpm/dynamic_observer/ct_scorematching.py:54: SyntaxWarning: invalid escape sequence '\i'
#   """

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 noise_schedule = ConstantTimeNoiseSchedule(0.05)
#
# TypeError: Can't instantiate abstract class ConstantTimeNoiseSchedule without an implementation for abstract methods 'beta', 'int_t_beta'
